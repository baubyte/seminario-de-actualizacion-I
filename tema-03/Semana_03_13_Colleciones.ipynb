# %% [markdown]
# ## Collections
#
# Python viene con un modulo que contiene varios contenedores de datos llamados colecciones o collections en Inglés. Hablaremos de algunos de ellos y de sus usos.
#
# En concreto, hablaremos de los siguientes:
#
# * defaultdict
# * OrderedDict
# * counter
# * deque
# * namedtuple
# * enum.Enum (fuera del módulo; Python 3.4+)

# %% [markdown]
# ## defaultdict
# A diferencia de dict con defaultdict no tienes que verificar que una llave o key este presente. Es decir, puedes hacer lo siguiente:

# %%
from collections import defaultdict

cities = (
    ('Asturias', 'Oviedo'),
    ('Galicia', 'Ourense'),
    ('Extremadura', 'Cáceres'),
    ('Galicia', 'Pontevedra'),
    ('Asturias', 'Gijón'),
    ('Cataluña', 'Barcelona'),
)

ciudades:defaultdict = defaultdict(list)
# cada vez que agrego una clave se inicializa con el tipo de dato que le pase,
# en este caso list
for name, city in cities:
    # Nótese que en ningún momento estoy inicializando las listas de cada key
    ciudades[name].append(city)

print(ciudades)
# Out:
# defaultdict(<class 'list'>, {'Asturias': ['Oviedo', 'Gijón'], 'Galicia': ['Ourense', 'Pontevedra'], 'Extremadura': ['Cáceres'], 'Cataluña': ['Barcelona']})

# %% [markdown]
# Una de las ocasiones en las que son más útiles, es si quieres añadir elementos a listas anidadas dentro e un diccionario. Si la llave o key no está ya presente en el diccionario, tendrás un error tipo KeyError. El uso de defaultdict permite evitar este problema. Antes de nada, vamos a ver un ejemplo con dict que daría un error KeyError como hemos mencionado, y después veremos la solución usando defaultdict.

# %%
import traceback

# %%
some_dict = {}
try:
  some_dict['region']['ciudad'] = "Oviedo"
except Exception:
  traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-3-fbb1b7dadf3d>", line 3, in <cell line: 2>
#     some_dict['region']['ciudad'] = "Oviedo"
# KeyError: 'region'

# %% [markdown]
# Solución:

# %%
from collections import defaultdict
# tree: es una función lambda que devuelve un defaultdict que se inicializa
#  con la misma función lambda
tree = lambda: defaultdict(tree)
# al instanciar la función tree se crea un defaultdict y luego cada vez
#  pido una key se genera un nuevo defaultdict
some_dict = tree()
some_dict['region']['ciudad'] = "Oviedo"
# ¡Funciona!

# %% [markdown]
# Ahora podrías imprimir también el diccionario some_dict usando json.dumps. Aquí tienes un ejemplo:

# %%
print(some_dict)
# Out:
# defaultdict(<function <lambda> at 0x7a4e91f5f2e0>, {'region': defaultdict(<function <lambda> at 0x7a4e91f5f2e0>, {'ciudad': 'Oviedo'})})

# %% [markdown]
# ## OrderedDict
# OrderedDict es un diccionario que mantiene ordenadas sus entradas según van siendo añadidas. Es importante saber también que sobreescribir un valor existente no cambia la posición de la llave o key. Sin embargo, eliminar y reinsertar una entrar mueve la llave al final del diccionario.
#
# Problema:

# %%
colours:dict =  {"Rojo" : 198, "Verde" : 170, "Azul" : 160}
for key, value in colours.items():
    print(key, value)
# Las entradas pueden ser recuperadas en un orden no predecible.
# Out:
# Rojo 198
# Verde 170
# Azul 160

# %% [markdown]
# Solución:

# %%
from collections import OrderedDict

colours:OrderedDict = OrderedDict([("Rojo", 198), ("Verde", 170), ("Azul", 160)])
for key, value in colours.items():
    print(key, value)
# El orden de inserción se mantiene.
# Out:
# Rojo 198
# Verde 170
# Azul 160

# %% [markdown]
# ## counter
# El uso de counter nos permite contar el número de elementos que una llave tiene. Por ejemplo, puede ser usado para contar el número de colores favoritos de diferentes personas.

# %%
from collections import Counter

colours:tuple = (
    ('Covadonga', 'Amarillo'),
    ('Pelayo', 'Azul'),
    ('Xavier', 'Verde'),
    ('Pelayo', 'Negro'),
    ('Covadonga', 'Rojo'),
    ('Amaya', 'Plata'),
)

favs = Counter(name for name, colour in colours)
print(favs)
# Out:
# Counter({'Covadonga': 2, 'Pelayo': 2, 'Xavier': 1, 'Amaya': 1})

# %% [markdown]
# También podemos contar las líneas más comunes de un fichero, como por ejemplo:

# %%
with open('./sample_data/README.md', 'rb') as f:
    line_count = Counter(f)
print(line_count)
# Out:
# Counter({b'\n': 5, b'This directory includes a few sample datasets to get you started.\n': 1, b'*   `california_housing_data*.csv` is California housing data from the 1990 US\n': 1, b'    Census; more information is available at:\n': 1, b'    https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub\n': 1, b'*   `mnist_*.csv` is a small sample of the\n': 1, b'    [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is\n': 1, b'    described at: http://yann.lecun.com/exdb/mnist/\n': 1, b'*   `anscombe.json` contains a copy of\n': 1, b"    [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it\n": 1, b'    was originally described in\n': 1, b"    Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American\n": 1, b'    Statistician. 27 (1): 17-21. JSTOR 2682899.\n': 1, b'    and our copy was prepared by the\n': 1, b'    [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).\n': 1})

# %% [markdown]
# ## deque
# deque proporciona una cola con dos lados, lo que significa que puedes añadir y eliminar elementos de cualquiera de los lados de la cola. Primero debes importar el módulo de la librería de colecciones o collections:

# %%
from collections import deque

# %% [markdown]
# Una vez importado ya podemos crear el objeto:

# %%
d:deque = deque()

# %% [markdown]
# Tienen un comportamiento relativamente similar a las conocidas listas de Python, y sus métodos son también similares. Puedes hacer lo siguiente:

# %%
d:deque = deque()
d.append('1')
d.append('2')
d.append('3')

print('Loguitud de deque:', len(d))

print('Primer elemento:',d[0])

print('último elemento:', d[-1])
# Out:
# Loguitud de deque: 3
# Primer elemento: 1
# último elemento: 3

# %% [markdown]
# También puedes tomar elementos de los dos lados de la cola, una funcionalidad conocida como pop. Es importante notar que pop devuelve el elemento eliminado.

# %%
d:deque = deque(range(5))
print('Deque tiene los elementos:', d)

print('Loguitud de deque:', len(d))

print('Se quitó el elemento:', d.popleft())

print('Se quitó el elemento:', d.popleft())

print('Deque tiene los elementos:', d)
# Out:
# Deque tiene los elementos: deque([0, 1, 2, 3, 4])
# Loguitud de deque: 5
# Se quitó el elemento: 0
# Se quitó el elemento: 1
# Deque tiene los elementos: deque([2, 3, 4])

# %% [markdown]
# También podemos limitar la cantidad de elementos que la cola deque puede almacenar. Al hacer esto, simplemente quitará elementos del otro lado de la cola si el límite es superado. Se ve mejor con un ejemplo como se muestra a continuación:

# %%
d:deque = deque([0, 1, 2, 3, 5], maxlen=5)
print('Deque tiene los elementos:', d)

d.extend([6])
print('Deque tiene los elementos:', d)
# Out:
# Deque tiene los elementos: deque([0, 1, 2, 3, 5], maxlen=5)
# Deque tiene los elementos: deque([1, 2, 3, 5, 6], maxlen=5)

# %% [markdown]
# Ahora cuando insertamos valores después del 5, la parte más a la izquierda será eliminada de la lista. También puedes expandir la lista en cualquier dirección con valores nuevos.

# %%
d:deque = deque([1,2,3,4,5])
print('Deque tiene los elementos:', d)
d.extendleft([0])
print('Deque tiene los elementos:', d)
d.extend([6,7,8])
print('Deque tiene los elementos:', d)
# Out:
# Deque tiene los elementos: deque([1, 2, 3, 4, 5])
# Deque tiene los elementos: deque([0, 1, 2, 3, 4, 5])
# Deque tiene los elementos: deque([0, 1, 2, 3, 4, 5, 6, 7, 8])

# %% [markdown]
# ## namedtuple
# Tal vez conozcas ya las tuplas, que son listas inmutables que permiten almacenar una secuencia de valores separados por coma. Son simplemente como las listas pero con algunas diferencias importantes. La principal es que a diferencia de las listas no puedes reasignar el valor de un elemento una vez inicializada. Para acceder a un índice de la tupla se hace de la siguiente manera:

# %%
man = ('Pelayo', 30)
print('El valor de la posición 0 es:', man[0])
# Out:
# El valor de la posición 0 es: Pelayo

# %% [markdown]
# Sabido esto, ¿qué son las namedtuples?. Se trata de un tipo que convierte las tuplas en contenedores bastante útiles para tareas simples. Con ellas, no necesitas usar índices enteros para acceder a los miembros de la misma. Puedes pensar en ellas como si fuesen diccionarios, con la salvedad de que son inmutables. Veamos un ejemplo.

# %%
from collections import namedtuple

# creamos un tipo denominado 'Animal' que posee las propiedades 'nombre', 'edad' y 'tipo'
Animal:namedtuple = namedtuple('Animal', 'nombre edad tipo')
# inicializamos una tupla 'Animal' con los valores para sus propiedades
perry:Animal = Animal(nombre="perry", edad=31, tipo="cat")

print('Mostrando perry:', perry)

print('Mostrando el nombre de perry:', perry.nombre)
# Out:
# Mostrando perry: Animal(nombre='perry', edad=31, tipo='cat')
# Mostrando el nombre de perry: perry

# %% [markdown]
# Puedes ver como es posible acceder a los elementos a través de su nombre, simplemente haciendo uso de `.`.
#
# Vamos a verlo con más detalle. Una namedtuple requiere de dos argumentos. Estos son, el nombre de la tupla y los campos de la misma. En el ejemplo anterior hemos visto como el nombre de la tupla era “Animal” y tenía tres atributos: “nombre”, “edad” y “tipo”.
#
# Las namedtuple son muy útiles ya que hacen que las tuplas tengan una especie de documentación propia, y apenas sea necesaria una explicación de como usarlas, ya que puedes verlo con un simple vistazo al código. Además, dado que no es necesario usar índices, hace que sea más fácil de mantener.
#
# Otra de las ventajas es que son bastante ligeras, y no necesitan mas memoria que las tuplas normales. Esto hace que sean mas rápidas que los diccionarios. Sin embargo, recuerda que los atributos de las tuplas son inmutables, por lo que no pueden ser modificados. El siguiente ejemplo no funcionaría:

# %%
from collections import namedtuple

Animal = namedtuple('Animal', 'nombre edad tipo')
perry = Animal(nombre="perry", edad=31, tipo="cat")
try:
  perry.edad = 42
except Exception:
  traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-18-3420d6660cc8>", line 6, in <cell line: 5>
#     perry.edad = 42
# AttributeError: can't set attribute

# %% [markdown]
# Deberías usar las namedtuple si quieres que tu código sea autodocumentado. Lo mejor de todo es que ofrecen compatibilidad con las tuplas, por lo que puedes indexarlas como si de una tupla normal se tratase. Veamos un ejemplo:

# %%
from collections import namedtuple

Animal = namedtuple('Animal', 'nombre edad tipo')
perry = Animal(nombre="perry", edad=31, tipo="cat")
print('Mostrando el nombre de perry que se encuentra en la posición [0]:', perry[0])
# Out:
# Mostrando el nombre de perry que se encuentra en la posición [0]: perry

# %% [markdown]
# Por último, aunque no por ello menos importante, puedes convertir una namedtuple en un diccionario. Se puede hacer de la siguiente manera:

# %%
from collections import namedtuple

Animal = namedtuple('Animal', 'nombre edad tipo')
perry = Animal(nombre="Perry", edad=31, tipo="cat")
print(perry._asdict())
# Out:
# {'nombre': 'Perry', 'edad': 31, 'tipo': 'cat'}

# %% [markdown]
# ## enum.Enum (Python 3.4+)
# Otra de las colecciones más útiles de Python es el tipo enum, que se encuentra disponible en el módulo enum desde Python 3.4 en adelante (también está disponible como backport en PyPI bajo el nombre enum32). Los enums (enumerated type) son básicamente una forma de organizar aquellos nombres que puedan tomar un determinado número de estados limitados y claramente definidos.
#
# Vamos a considerar el ejemplo anterior en namedtuples del Animal. Si recuerdas, había un campo denominado tipo. El problema de este tipo es que era una cadena. ¿Qué pasaría si escribimos Gato o GATO?
#
# El uso de enum nos puede ayudar a resolver este problema, evitando por lo tanto usar cadenas. Veamos el siguiente ejemplo:

# %%
from collections import namedtuple
from enum import Enum

class Especies(Enum):
    gato = 1
    perro = 2
    caballo = 3
    lobo = 4
    mariposa = 5
    buho = 6
    # ¡Y muchos más!

    # Se pueden usar también alias
    gatito = 1
    perrito = 2

Animal = namedtuple('Animal', 'name age type')
perry = Animal(name="Perry", age=31, type=Especies.gato)
caballo = Animal(name="HorseLuis", age=4, type=Especies.caballo)
tom = Animal(name="Tom", age=75, type=Especies.lobo)
luna = Animal(name="Luna", age=35, type=Especies.gatito)

# Y un ejemplo
print('El tipo de perry es igual al tipo de luna:', perry.type == luna.type)
print('El tipo de luna es:', luna.type)
# Out:
# El tipo de perry es igual al tipo de luna: True
# El tipo de luna es: Especies.gato

# %% [markdown]
# Un código así es mucho menos propenso a tener fallos. Si necesitamos ser específicos, deberíamos usar sólo los tipos enumerados.
#
# Por último, existen tres formas de acceder a los enum. Sigamos con el ejemplo anterior de las especies. Vamos a acceder a gato:

# %%
Especies(1)
# Out:
# <Especies.gato: 1>

# %%
Especies['gato']
# Out:
# <Especies.gato: 1>

# %%
Especies.gato
# Out:
# <Especies.gato: 1>

# %%
print(Especies(1))
print(Especies['gato'])
print(Especies.gato)
# Out:
# Especies.gato
# Especies.gato
# Especies.gato

# %% [markdown]
# Con esto finalizamos una breve introducción al módulo de collections de Python. Si quieres saber más, te recomendamos que leas la documentación oficial de Python, que aunque pueda ser un poco más técnica y menos didáctica, con esta introducción ya deberías estar listo para entenderla.
