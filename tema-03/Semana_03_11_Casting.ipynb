# %% [markdown]
# ## Cast en Python
#
# Hacer un cast o casting significa convertir un tipo de dato a otro. Anteriormente hemos visto tipos como los int, str o float. Pues bien, es posible convertir de un tipo a otro.
#
# Pero antes de nada, veamos los diferentes tipos de cast o conversión de tipos que se pueden hacer.
#
# Existen dos:
#
# * Conversión implícita: Es realizada automáticamente por Python. Sucede cuando realizamos ciertas operaciones con dos tipos distintos.
#
# * Conversión explícita: Es realizada expresamente por nosotros, como por ejemplo convertir de str a int con str().

# %% [markdown]
# ## Conversión implícita
# Esta conversión de tipos es realizada automáticamente por Python, prácticamente sin que nos demos cuenta. Aún así, es importante saber lo que pasa por debajo para evitar problemas futuros.
#
# El ejemplo más sencillo donde podemos ver este comportamiento es el siguiente:
# * a es un int
# * b es un float
#
# Pero si sumamos a + b y almacenamos el resultado en a, podemos ver como internamente Python ha convertido el int en float para poder realizar la operación, y la variable resultante es float

# %%
a:int = 1
b:float = 2.3
print('El tipo de la variable a antes de sumar es: ', type(a))

print(f'El resultado de sumar {a}+{b} es: ', end='', sep='' )
a:float = a + b
print(a)
print('El tipo de la variable a después de sumar es: ', type(a))
# Out:
# El tipo de la variable a antes de sumar es:  <class 'int'>
# El resultado de sumar 1+2.3 es: 3.3
# El tipo de la variable a después de sumar es:  <class 'float'>

# %% [markdown]
# Sin embargo hay otros casos donde Python no es tan listo y no es capaz de realizar la conversión. Si intentamos sumar un int a un string, tendremos un error TypeError.

# %%
import traceback

# %%
a:int = 1
b:str = "2.3"
try:
  c = a + b
except Exception:
  traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-3-b869e9d3acc5>", line 4, in <cell line: 3>
#     c = a + b
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# Si te das cuenta, es lógico que esto sea así, ya que en este caso b era "2.3", pero ¿y si fuera "Hola"? ¿Cómo se podría sumar eso? No tiene sentido.

# %% [markdown]
# ## Conversión explicita
# Por otro lado, podemos hacer conversiones entre tipos o cast de manera explícita haciendo uso de diferentes funciones que nos proporciona Python. Las más usadas son las siguientes:
#
# * float(), str(), int(), list(), set()
# * Y algunas otras como hex(), oct() y bin()

# %% [markdown]
# ### Convertir float a int
# Para convertir de float a int debemos usar float(). Pero mucho cuidado, ya que el tipo entero no puede almacena decimales, por lo que perderemos lo que haya después de la coma.

# %%
a:float = 3.5
print('El valor de la variable a es: ', a)
a:int = int(a)
print('El valor de la variable a luego del casting es: ', a)
print('El tipo de la variable a es: ', type(a))
# Out:
# El valor de la variable a es:  3.5
# El valor de la variable a luego del casting es:  3
# El tipo de la variable a es:  <class 'int'>

# %% [markdown]
# ### Convertir float a string
# Podemos convertir un float a string con str(). Podemos ver en el siguiente código como cambia el tipo de a después de hacer el cast.

# %%
a:float = 3.5
print('El valor de la variable a es: ', a)
print('El tipo de la variable a es: ', type(a))
a:str = str(a)
print('El valor de la variable a es: ', a)
print('El tipo de la variable a luego de realizar el casting es: ', type(a))
# Out:
# El valor de la variable a es:  3.5
# El tipo de la variable a es:  <class 'float'>
# El valor de la variable a es:  3.5
# El tipo de la variable a luego de realizar el casting es:  <class 'str'>

# %% [markdown]
# ### Convertir string a float
# Podemos convertir un string a float usando float(). Es importante notar que se usa el . como separador.

# %%
a:str = "35.5"
print(float(a))
# Out:
# 35.5

# %% [markdown]
# El siguiente código daría un error, dado que , no se reconoce por defecto como separador decimal.

# %%
a:str = "35,5"
try:
  print(float(a))
except Exception:
  traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-7-8cb1622e502b>", line 3, in <cell line: 2>
#     print(float(a))
# ValueError: could not convert string to float: '35,5'

# %% [markdown]
# Y por último, resulta obvio pensar que el siguiente código dará un error también.

# %%
a:str = "Python"
try:
  a:float = float(a)
except Exception:
  traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-8-efba8b37c356>", line 3, in <cell line: 2>
#     a:float = float(a)
# ValueError: could not convert string to float: 'Python'

# %% [markdown]
# ### Convertir string a int
# Al igual que la conversión a float del caso anterior, podemos convertir de string a int usando int().

# %%
a:str = "3"
print('El valor de la variable a es: ', a)
print('El tipo de la variable a es: ', type(a))
a:int = int(a)
print('El valor de la variable a es: ', a)
print('El tipo de la variable a luego de realizar el casting es: ', type(a))
# Out:
# El valor de la variable a es:  3
# El tipo de la variable a es:  <class 'str'>
# El valor de la variable a es:  3
# El tipo de la variable a luego de realizar el casting es:  <class 'int'>

# %% [markdown]
# Cuidado ya que no es posible convertir a int cualquier valor.

# %%
a:str = "Python"
try:
  a:int = int(a)
except Exception:
  traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-10-7193e9edd8eb>", line 3, in <cell line: 2>
#     a:int = int(a)
# ValueError: invalid literal for int() with base 10: 'Python'

# %% [markdown]
# ### Convertir int a string
# La conversión de int a string se puede realizar con str().
#
# A diferencia de otras conversiones, esta puede hacerse siempre, ya que cualquier valor entero que se nos ocurra poner en a, podrá ser convertido a string.

# %%
a:int = 10
print('El valor de la variable a es: ', a)
print('El tipo de la variable a es: ', type(a))
a:str = str(a)
print('El valor de la variable a es: ', a)
print('El tipo de la variable a luego de realizar el casting es: ', type(a))
# Out:
# El valor de la variable a es:  10
# El tipo de la variable a es:  <class 'int'>
# El valor de la variable a es:  10
# El tipo de la variable a luego de realizar el casting es:  <class 'str'>

# %% [markdown]
# ### Convertir a list
# Es también posible hacer un cast a lista, desde por ejemplo un set. Para ello podemos usar list().

# %%
a:set = {1, 2, 3}
b:list = list(a)

print('El valor de la variable a es: ', a)
print('El tipo de la variable a es: ', type(a))
print('El valor de la variable b es: ', b)
print('El tipo de la variable b es: ', type(b))
# Out:
# El valor de la variable a es:  {1, 2, 3}
# El tipo de la variable a es:  <class 'set'>
# El valor de la variable b es:  [1, 2, 3]
# El tipo de la variable b es:  <class 'list'>

# %% [markdown]
# ### Convertir a set
# Y de manera completamente análoga, podemos convertir de lista a set haciendo uso de set().

# %%
a:list = ["Python", "Mola"]
b:set = set(a)

print('El valor de la variable a es: ', a)
print('El tipo de la variable a es: ', type(a))
print('El valor de la variable b es: ', b)
print('El tipo de la variable b es: ', type(b))
# Out:
# El valor de la variable a es:  ['Python', 'Mola']
# El tipo de la variable a es:  <class 'list'>
# El valor de la variable b es:  {'Python', 'Mola'}
# El tipo de la variable b es:  <class 'set'>

# %% [markdown]
# Esperamos que esto haya servido para aclarar el concepto de casts o conversiones de tipos en Python. Es muy importante tener bien claro el tipo de datos con el que estamos trabajando en cada momento, ya que Python es un lenguaje con tipado dinámico, algo que puede ser una gran ventaja, pero también causa de muchos quebraderos de cabeza.
#
# Y recuerda, la función type() es tu amiga.
#
# Si quieres saber más, tal vez te interese el concepto de duck typing.
