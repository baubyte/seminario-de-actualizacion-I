# %% [markdown]
# ## dict
# Los diccionarios en Python son una estructura de datos que permite almacenar su contenido en forma de llave y valor.

# %% [markdown]
# Puedes obtener más ayuda con el comando help.

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the dict keys.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  get(self, key, default=None, /)
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |
#  |      If the key is not found, return the default if given; otherwise,
#  |      raise a KeyError.
#  |
#  |  popitem(self, /)
#  |      Remove and return a (key, value) pair as a 2-tuple.
#  |
#  |      Pairs are returned in LIFO (last-in, first-out) order.
#  |      Raises KeyError if the dict is empty.
#  |
#  |  setdefault(self, key, default=None, /)
#  |      Insert key with a value of default if key is not in the dictionary.
#  |
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(...) from builtins.type
#  |      See PEP 585
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Create a new dictionary with keys from iterable and values set to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %% [markdown]
# ## Crear diccionario Python
# Un diccionario en Python es una colección de elementos, donde cada uno tiene una llave `key` y un valor `value` asociado a la key. Los diccionarios se pueden crear con paréntesis `{}` separando con una coma cada par `key: value`. En el siguiente ejemplo tenemos tres keys que son el nombre, la edad y el documento.

# %%
d1:dict = {
  "Nombre": "Sara",
  "Edad": 27,
  "Documento": 1003882
}
print('La variable d1 contiene:', d1)
# Out:
# La variable d1 contiene: {'Nombre': 'Sara', 'Edad': 27, 'Documento': 1003882}

# %% [markdown]
# Otra opción es importar `Dict` desde el módulo de typing.

# %%
from typing import Dict

d1:Dict = {
  "Nombre": "Sara",
  "Edad": 27,
  "Documento": 1003882
}
print('La variable d1 contiene:', d1)
# Out:
# La variable d1 contiene: {'Nombre': 'Sara', 'Edad': 27, 'Documento': 1003882}

# %% [markdown]
# Otra forma equivalente de crear un diccionario en Python es usando `dict()` e introduciendo los pares `key: value` entre paréntesis.

# %%
d2:dict = dict([
      ('Nombre', 'Sara'),
      ('Edad', 27),
      ('Documento', 1003882),
])
print('La variable d2 contiene:', d2)
# Out:
# La variable d2 contiene: {'Nombre': 'Sara', 'Edad': 27, 'Documento': 1003882}

# %% [markdown]
# También es posible usar el constructor `dict()` para crear un diccionario.

# %%
d3:dict = dict(Nombre='Sara',
          Edad=27,
          Documento=1003882)
print('La variable d3 contiene:', d3)
# Out:
# La variable d3 contiene: {'Nombre': 'Sara', 'Edad': 27, 'Documento': 1003882}

# %% [markdown]
# Algunas propiedades de los diccionario en Python son las siguientes:
#
# * Son dinámicos, pueden crecer o decrecer, se pueden añadir o eliminar elementos.
# * Son indexados, los elementos del diccionario son accesibles a través del key.
# * Y son anidados, un diccionario puede contener a otro diccionario en su campo value.

# %% [markdown]
# ## Acceder y modificar elementos
# Se puede acceder a sus elementos con [] o también con la función get()

# %%
print(d1['Nombre'])
print(d1.get('Nombre'))
# Out:
# Sara
# Sara

# %% [markdown]
# Para modificar un elemento basta con usar [] con el nombre del key y asignar el valor que queremos.

# %%
print('La variable d1 contiene:', d1)
d1['Nombre'] = "Laura"
print('La variable d1 contiene:', d1)
# Out:
# La variable d1 contiene: {'Nombre': 'Sara', 'Edad': 27, 'Documento': 1003882}
# La variable d1 contiene: {'Nombre': 'Laura', 'Edad': 27, 'Documento': 1003882}

# %% [markdown]
# Si el key al que accedemos no existe, se añade automáticamente.

# %%
print('La variable d1 contiene:', d1)
d1['Direccion'] = "Calle 123"
print('La variable d1 contiene:', d1)
# Out:
# La variable d1 contiene: {'Nombre': 'Laura', 'Edad': 27, 'Documento': 1003882}
# La variable d1 contiene: {'Nombre': 'Laura', 'Edad': 27, 'Documento': 1003882, 'Direccion': 'Calle 123'}

# %% [markdown]
# ## Iterar diccionario
# Los diccionarios se pueden iterar de manera muy similar a las listas u otras estructuras de datos. Para imprimir los key.

# %%
for x in d1:
    print(x)
# Out:
# Nombre
# Edad
# Documento
# Direccion

# %% [markdown]
# Se puede imprimir también solo el value.

# %%
for x in d1:
    print(f"Clave: {x} - valor: {d1[x]}")
# Out:
# Clave: Nombre - valor: Laura
# Clave: Edad - valor: 27
# Clave: Documento - valor: 1003882
# Clave: Direccion - valor: Calle 123

# %% [markdown]
# O si queremos imprimir el key y el value a la vez.

# %%
for key, value in d1.items():
    print(key, value)
# Out:
# Nombre Laura
# Edad 27
# Documento 1003882
# Direccion Calle 123

# %% [markdown]
# ## Diccionarios anidados
# Los diccionarios en Python pueden contener uno dentro de otro. Podemos ver como los valores anidado uno y dos del diccionario d contienen a su vez otro diccionario.

# %%
anidado1:dict = {"a": 1, "b": 2}
anidado2:dict = {"a": 1, "b": 2}
d:dict = {
  "anidado1" : anidado1,
  "anidado2" : anidado2
}
print('La variable d contiene:', d)
# Out:
# La variable d contiene: {'anidado1': {'a': 1, 'b': 2}, 'anidado2': {'a': 1, 'b': 2}}

# %% [markdown]
# ## Métodos diccionarios Python

# %% [markdown]
# ### clear()
# El método clear() elimina todo el contenido del diccionario.

# %%
d:dict = {'a': 1, 'b': 2}
print('La variable d contiene:', d)
d.clear()
print('La variable d contiene:', d)
# Out:
# La variable d contiene: {'a': 1, 'b': 2}
# La variable d contiene: {}

# %% [markdown]
# ### get(key[,default])
# El método get() nos permite consultar el value para un key determinado. El segundo parámetro es opcional, y en el caso de proporcionarlo es el valor a devolver si no se encuentra la key.

# %%
d:dict = {'a': 1, 'b': 2}
print(d.get('a'))
print(d.get('z', 'No encontrado'))
# Out:
# 1
# No encontrado

# %% [markdown]
# ### items()
# El método items() devuelve una lista con los keys y values del diccionario. Si se convierte en list se puede indexar como si de una lista normal se tratase, siendo los primeros elementos las key y los segundos los value.

# %%
d:dict = {'a': 1, 'b': 2}
it = d.items()
print(it)
print(list(it))
print(list(it)[0][0])
# Out:
# dict_items([('a', 1), ('b', 2)])
# [('a', 1), ('b', 2)]
# a

# %% [markdown]
# ### keys()
# El método keys() devuelve una lista con todas las keys del diccionario.

# %%
d:dict = {'a': 1, 'b': 2}
k = d.keys()
print(k)
print(list(k))
# Out:
# dict_keys(['a', 'b'])
# ['a', 'b']

# %% [markdown]
# ### values()
# El método values() devuelve una lista con todos los values o valores del diccionario.

# %%
d:dict = {'a': 1, 'b': 2}
print(list(d.values()))
# Out:
# [1, 2]

# %% [markdown]
# ### pop(key[,default])
# El método pop() busca y elimina la key que se pasa como parámetro y devuelve su valor asociado. Daría un error si se intenta eliminar una key que no existe.

# %%
d:dict = {'a': 1, 'b': 2}
print('La variable d contiene:', d)
valor_a:int = d.pop('a')
print('La variable d contiene:', d)
print('El valor extraido es: ', valor_a)
# Out:
# La variable d contiene: {'a': 1, 'b': 2}
# La variable d contiene: {'b': 2}
# El valor extraido es:  1

# %% [markdown]
# También se puede pasar un segundo parámetro que es el valor a devolver si la key no se ha encontrado. En este caso si no se encuentra no habría error.

# %%
d:dict = {'a': 1, 'b': 2}
print('La variable d contiene:', d)
valor_c: int = d.pop('c', -1)
print('La variable d contiene:', d)
print('El valor extraido es: ', valor_c)
# Out:
# La variable d contiene: {'a': 1, 'b': 2}
# La variable d contiene: {'a': 1, 'b': 2}
# El valor extraido es:  -1

# %% [markdown]
# ### popitem()
# El método popitem() elimina el último elemento del diccionario.

# %%
d:dict = {'a': 1, 'b': 2}
print('La variable d contiene:', d)
d.popitem()
print('La variable d contiene:', d)
# Out:
# La variable d contiene: {'a': 1, 'b': 2}
# La variable d contiene: {'a': 1}

# %% [markdown]
# ### update(obj)
# El método update() se llama sobre un diccionario y tiene como entrada otro diccionario. Los value son actualizados y si alguna key del nuevo diccionario no esta, es añadida.

# %%
d1:dict = {'a': 1, 'b': 2}
d2:dict = {'a': 0, 'd': 400}
print('La variable d contiene:', d1)
d1.update(d2)
print('La variable d contiene:', d1)
# Out:
# La variable d contiene: {'a': 1, 'b': 2}
# La variable d contiene: {'a': 0, 'b': 2, 'd': 400}
